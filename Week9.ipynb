# %% [markdown]
# <a href="https://colab.research.google.com/github/novita824/PCVK_Genap_2023/blob/main/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accesing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/content/drive/MyDrive/PCVK(gambar)/morphology.png')
plt.imshow(img)

# %%
kernel = np.ones((3,3), np.uint8)
dilation = cv2.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title("Citra Awal")
plt.subplot(122),plt.imshow(dilation),plt.title("Citra Hasil Dilasi")
# Out:
# (<Axes: title={'center': 'Citra Hasil Dilasi'}>,
#  <matplotlib.image.AxesImage at 0x7f35410b2dc0>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
kernel = np.ones((3,3), np.uint8)
erosion = cv2.morphologyEx(img, cv2.MORPH_DILATE, kernel)

plt.subplot(121),plt.imshow(img),plt.title("Citra Awal")
plt.subplot(122),plt.imshow(erosion),plt.title("Citra Hasil Erosi")
# Out:
# (<Axes: title={'center': 'Citra Hasil Erosi'}>,
#  <matplotlib.image.AxesImage at 0x7f3540fcc640>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
img = cv2.imread('/content/drive/MyDrive/PCVK(gambar)/j.png')
plt.imshow(img)

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)

plt.subplot(121),plt.imshow(img),plt.title("Citra Awal")
plt.subplot(122),plt.imshow(erosion),plt.title("Citra Hasil Erosi")
# Out:
# (<Axes: title={'center': 'Citra Hasil Erosi'}>,
#  <matplotlib.image.AxesImage at 0x7f35412e47f0>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
img = cv2.imread('/content/drive/MyDrive/PCVK(gambar)/fingerprint.png')
plt.imshow(img)

# %%
kernel = np.ones((3,3), np.uint8)
erosion = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)

plt.subplot(121),plt.imshow(img),plt.title("Citra Awal")
plt.subplot(122),plt.imshow(erosion),plt.title("Citra Hasil Erosi")
# Out:
# (<Axes: title={'center': 'Citra Hasil Erosi'}>,
#  <matplotlib.image.AxesImage at 0x7f35407a29d0>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
kernel = np.ones((3,3), np.uint8)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

plt.subplot(121),plt.imshow(opening),plt.title("Citra Hasil Opening")
# Out:
# (<Axes: title={'center': 'Citra Hasil Opening'}>,
#  <matplotlib.image.AxesImage at 0x7f35406c77c0>,
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %%
kernel = np.ones((3,3), np.uint8)
erosion = cv2.morphologyEx(img, cv2.MORPH_DILATE, kernel)

plt.subplot(121),plt.imshow(img),plt.title("Citra Awal")
plt.subplot(122),plt.imshow(erosion),plt.title("Citra Hasil Dilasi")
# Out:
# (<Axes: title={'center': 'Citra Hasil Dilasi'}>,
#  <matplotlib.image.AxesImage at 0x7f35404cbee0>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
kernel = np.ones((3,3), np.uint8)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

plt.subplot(121),plt.imshow(closing),plt.title("Citra Hasil Closing")
# Out:
# (<Axes: title={'center': 'Citra Hasil Closing'}>,
#  <matplotlib.image.AxesImage at 0x7f354042c340>,
#  Text(0.5, 1.0, 'Citra Hasil Closing'))
